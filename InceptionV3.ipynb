# %% [markdown]
# <a href="https://colab.research.google.com/github/agolbeny/Alert-app-1/blob/main/InceptionV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from tqdm import tqdm # for progress bar

# Libraries for TensorFlow
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras import models, layers
from tensorflow import keras

# Library for Transfer Learning
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import preprocess_input

print("Importing libraries completed.")
# Out:
# Importing libraries completed.

# %%
(xtrain,ytrain),(xtest,ytest)= keras.datasets.mnist.load_data()

# %%
# Verifying dataset

print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
print(ytrain)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# [5 0 4 ... 5 6 8]

# %%
# Convert the images into 3 channels as MNIST images are Black and White so have 1 channel

xtrain=np.dstack([xtrain] * 3)
xtest=np.dstack([xtest]*3)
xtrain.shape,xtest.shape
# Out:
# ((60000, 28, 84), (10000, 28, 84))

# %%
# Reshape images as per the tensor format required by tensorflow

xtrain = xtrain.reshape(-1, 28,28,3)
xtest= xtest.reshape (-1,28,28,3)
xtrain.shape,xtest.shape
# Out:
# ((60000, 28, 28, 3), (10000, 28, 28, 3))

# %%
from tensorflow.keras.utils import img_to_array, array_to_img

xtrain = np.asarray([img_to_array(array_to_img(im, scale=False).resize((48,48))) for im in xtrain])
xtest = np.asarray([img_to_array(array_to_img(im, scale=False).resize((48,48))) for im in xtest])
#train_x = preprocess_input(x)
xtrain.shape, xtest.shape
# Out:
# ((60000, 48, 48, 3), (10000, 48, 48, 3))

# %%
# listing the folders containing images

# preparing array that can be used later

class_names=['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
print(class_names)

val_class_names =['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
print(val_class_names)

test_class_names=['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
print(test_class_names)

# Function to know the name of the element

def Get_Element_Name(argument):
    switcher = {
        0: "Zero",
        1: "One",
        2: "Two",
        3: "Three",
        4: "Four",
        5: "Five",
        6: "Six",
        7: "Seven",
        8: "Eight",
        9: "Nine",
    }
    return switcher.get(argument, "Invalid")

print(Get_Element_Name(0))
# Out:
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# Zero

# %%
# Preparing data

x=[] # to store array value of the images
x=xtrain
y=[] # to store the labels of the images
y=ytrain

test_images=[]
test_images=xtest
test_images_Original=[]
test_images_Original=xtest
test_image_label=[] # to store the labels of the images
test_image_label=ytest

val_images=[]
val_images=xtest
val_images_Original=[]
val_images_Original=xtest
val_image_label=[] # to store the labels of the images
val_image_label=ytest # to store the labels of the images

print("Preparing Dataset Completed.")
# Out:
# Preparing Dataset Completed.

# %%
# Verifying the output

# Training Dataset
print("Training Dataset")

x=np.array(x) # Converting to np arrary to pass to the model
print(x.shape)

y=to_categorical(y) # onehot encoding of the labels
# print(y)
print(y.shape)

# Test Dataset
print("Test Dataset")

test_images=np.array(test_images) 
print(test_images.shape)

test_image_label=to_categorical(test_image_label) # onehot encoding of the labels)
print(test_image_label.shape)

# Validation Dataset
print("Validation Dataset")

val_images=np.array(val_images) 
print(val_images.shape)

val_image_label=to_categorical(val_image_label) # onehot encoding of the labels)
print(val_image_label.shape)
# Out:
# Training Dataset
# (60000, 48, 48, 3)
# (60000, 10)
# Test Dataset
# (10000, 48, 48, 3)
# (10000, 10)
# Validation Dataset
# (10000, 48, 48, 3)
# (10000, 10)

# %%
# Check properties of the model that we are going to use for Transfer Learning

print("Summary of default inception_v3 model.\n")

# we are using VGG16 for transfer learnin here. So we have imported it
from tensorflow.keras.applications.inception_v3 import InceptionV3

# initializing model with weights='imagenet'i.e. we are carring its original weights
model_inception_v3=InceptionV3(weights='imagenet')

# display the summary to see the properties of the model
model_inception_v3.summary()
# Out:
# Summary of default inception_v3 model.
#
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_758 (Conv2D)            (None, 149, 149, 32  864         ['input_18[0][0]']
#                                 )
#
#  batch_normalization_754 (Batch  (None, 149, 149, 32  96         ['conv2d_758[0][0]']
#  Normalization)                 )
#
#  activation_754 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_754[0][0]']
#                                 )
#
#  conv2d_759 (Conv2D)            (None, 147, 147, 32  9216        ['activation_754[0][0]']
#                                 )
#
#  batch_normalization_755 (Batch  (None, 147, 147, 32  96         ['conv2d_759[0][0]']
#  Normalization)                 )
#
#  activation_755 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_755[0][0]']
#                                 )
#
#  conv2d_760 (Conv2D)            (None, 147, 147, 64  18432       ['activation_755[0][0]']
#                                 )
#
#  batch_normalization_756 (Batch  (None, 147, 147, 64  192        ['conv2d_760[0][0]']
#  Normalization)                 )
#
#  activation_756 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_756[0][0]']
#                                 )
#
#  max_pooling2d_32 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_756[0][0]']
#  )
#
#  conv2d_761 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_32[0][0]']
#
#  batch_normalization_757 (Batch  (None, 73, 73, 80)  240         ['conv2d_761[0][0]']
#  Normalization)
#
#  activation_757 (Activation)    (None, 73, 73, 80)   0           ['batch_normalization_757[0][0]']
#
#  conv2d_762 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_757[0][0]']
#
#  batch_normalization_758 (Batch  (None, 71, 71, 192)  576        ['conv2d_762[0][0]']
#  Normalization)
#
#  activation_758 (Activation)    (None, 71, 71, 192)  0           ['batch_normalization_758[0][0]']
#
#  max_pooling2d_33 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_758[0][0]']
#  )
#
#  conv2d_766 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_33[0][0]']
#
#  batch_normalization_762 (Batch  (None, 35, 35, 64)  192         ['conv2d_766[0][0]']
#  Normalization)
#
#  activation_762 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_762[0][0]']
#
#  conv2d_764 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_33[0][0]']
#
#  conv2d_767 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_762[0][0]']
#
#  batch_normalization_760 (Batch  (None, 35, 35, 48)  144         ['conv2d_764[0][0]']
#  Normalization)
#
#  batch_normalization_763 (Batch  (None, 35, 35, 96)  288         ['conv2d_767[0][0]']
#  Normalization)
#
#  activation_760 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_760[0][0]']
#
#  activation_763 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_763[0][0]']
#
#  average_pooling2d_73 (AverageP  (None, 35, 35, 192)  0          ['max_pooling2d_33[0][0]']
#  ooling2D)
#
#  conv2d_763 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_33[0][0]']
#
#  conv2d_765 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_760[0][0]']
#
#  conv2d_768 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_763[0][0]']
#
#  conv2d_769 (Conv2D)            (None, 35, 35, 32)   6144        ['average_pooling2d_73[0][0]']
#
#  batch_normalization_759 (Batch  (None, 35, 35, 64)  192         ['conv2d_763[0][0]']
#  Normalization)
#
#  batch_normalization_761 (Batch  (None, 35, 35, 64)  192         ['conv2d_765[0][0]']
#  Normalization)
#
#  batch_normalization_764 (Batch  (None, 35, 35, 96)  288         ['conv2d_768[0][0]']
#  Normalization)
#
#  batch_normalization_765 (Batch  (None, 35, 35, 32)  96          ['conv2d_769[0][0]']
#  Normalization)
#
#  activation_759 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_759[0][0]']
#
#  activation_761 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_761[0][0]']
#
#  activation_764 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_764[0][0]']
#
#  activation_765 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_765[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_759[0][0]',
#                                                                   'activation_761[0][0]',
#                                                                   'activation_764[0][0]',
#                                                                   'activation_765[0][0]']
#
#  conv2d_773 (Conv2D)            (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_769 (Batch  (None, 35, 35, 64)  192         ['conv2d_773[0][0]']
#  Normalization)
#
#  activation_769 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_769[0][0]']
#
#  conv2d_771 (Conv2D)            (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_774 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_769[0][0]']
#
#  batch_normalization_767 (Batch  (None, 35, 35, 48)  144         ['conv2d_771[0][0]']
#  Normalization)
#
#  batch_normalization_770 (Batch  (None, 35, 35, 96)  288         ['conv2d_774[0][0]']
#  Normalization)
#
#  activation_767 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_767[0][0]']
#
#  activation_770 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_770[0][0]']
#
#  average_pooling2d_74 (AverageP  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_770 (Conv2D)            (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_772 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_767[0][0]']
#
#  conv2d_775 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_770[0][0]']
#
#  conv2d_776 (Conv2D)            (None, 35, 35, 64)   16384       ['average_pooling2d_74[0][0]']
#
#  batch_normalization_766 (Batch  (None, 35, 35, 64)  192         ['conv2d_770[0][0]']
#  Normalization)
#
#  batch_normalization_768 (Batch  (None, 35, 35, 64)  192         ['conv2d_772[0][0]']
#  Normalization)
#
#  batch_normalization_771 (Batch  (None, 35, 35, 96)  288         ['conv2d_775[0][0]']
#  Normalization)
#
#  batch_normalization_772 (Batch  (None, 35, 35, 64)  192         ['conv2d_776[0][0]']
#  Normalization)
#
#  activation_766 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_766[0][0]']
#
#  activation_768 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_768[0][0]']
#
#  activation_771 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_771[0][0]']
#
#  activation_772 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_772[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_766[0][0]',
#                                                                   'activation_768[0][0]',
#                                                                   'activation_771[0][0]',
#                                                                   'activation_772[0][0]']
#
#  conv2d_780 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_776 (Batch  (None, 35, 35, 64)  192         ['conv2d_780[0][0]']
#  Normalization)
#
#  activation_776 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_776[0][0]']
#
#  conv2d_778 (Conv2D)            (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_781 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_776[0][0]']
#
#  batch_normalization_774 (Batch  (None, 35, 35, 48)  144         ['conv2d_778[0][0]']
#  Normalization)
#
#  batch_normalization_777 (Batch  (None, 35, 35, 96)  288         ['conv2d_781[0][0]']
#  Normalization)
#
#  activation_774 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_774[0][0]']
#
#  activation_777 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_777[0][0]']
#
#  average_pooling2d_75 (AverageP  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_777 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_779 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_774[0][0]']
#
#  conv2d_782 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_777[0][0]']
#
#  conv2d_783 (Conv2D)            (None, 35, 35, 64)   18432       ['average_pooling2d_75[0][0]']
#
#  batch_normalization_773 (Batch  (None, 35, 35, 64)  192         ['conv2d_777[0][0]']
#  Normalization)
#
#  batch_normalization_775 (Batch  (None, 35, 35, 64)  192         ['conv2d_779[0][0]']
#  Normalization)
#
#  batch_normalization_778 (Batch  (None, 35, 35, 96)  288         ['conv2d_782[0][0]']
#  Normalization)
#
#  batch_normalization_779 (Batch  (None, 35, 35, 64)  192         ['conv2d_783[0][0]']
#  Normalization)
#
#  activation_773 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_773[0][0]']
#
#  activation_775 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_775[0][0]']
#
#  activation_778 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_778[0][0]']
#
#  activation_779 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_779[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_773[0][0]',
#                                                                   'activation_775[0][0]',
#                                                                   'activation_778[0][0]',
#                                                                   'activation_779[0][0]']
#
#  conv2d_785 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_781 (Batch  (None, 35, 35, 64)  192         ['conv2d_785[0][0]']
#  Normalization)
#
#  activation_781 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_781[0][0]']
#
#  conv2d_786 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_781[0][0]']
#
#  batch_normalization_782 (Batch  (None, 35, 35, 96)  288         ['conv2d_786[0][0]']
#  Normalization)
#
#  activation_782 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_782[0][0]']
#
#  conv2d_784 (Conv2D)            (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_787 (Conv2D)            (None, 17, 17, 96)   82944       ['activation_782[0][0]']
#
#  batch_normalization_780 (Batch  (None, 17, 17, 384)  1152       ['conv2d_784[0][0]']
#  Normalization)
#
#  batch_normalization_783 (Batch  (None, 17, 17, 96)  288         ['conv2d_787[0][0]']
#  Normalization)
#
#  activation_780 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_780[0][0]']
#
#  activation_783 (Activation)    (None, 17, 17, 96)   0           ['batch_normalization_783[0][0]']
#
#  max_pooling2d_34 (MaxPooling2D  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_780[0][0]',
#                                                                   'activation_783[0][0]',
#                                                                   'max_pooling2d_34[0][0]']
#
#  conv2d_792 (Conv2D)            (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_788 (Batch  (None, 17, 17, 128)  384        ['conv2d_792[0][0]']
#  Normalization)
#
#  activation_788 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_788[0][0]']
#
#  conv2d_793 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_788[0][0]']
#
#  batch_normalization_789 (Batch  (None, 17, 17, 128)  384        ['conv2d_793[0][0]']
#  Normalization)
#
#  activation_789 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_789[0][0]']
#
#  conv2d_789 (Conv2D)            (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_794 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_789[0][0]']
#
#  batch_normalization_785 (Batch  (None, 17, 17, 128)  384        ['conv2d_789[0][0]']
#  Normalization)
#
#  batch_normalization_790 (Batch  (None, 17, 17, 128)  384        ['conv2d_794[0][0]']
#  Normalization)
#
#  activation_785 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_785[0][0]']
#
#  activation_790 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_790[0][0]']
#
#  conv2d_790 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_785[0][0]']
#
#  conv2d_795 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_790[0][0]']
#
#  batch_normalization_786 (Batch  (None, 17, 17, 128)  384        ['conv2d_790[0][0]']
#  Normalization)
#
#  batch_normalization_791 (Batch  (None, 17, 17, 128)  384        ['conv2d_795[0][0]']
#  Normalization)
#
#  activation_786 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_786[0][0]']
#
#  activation_791 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_791[0][0]']
#
#  average_pooling2d_76 (AverageP  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_788 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_791 (Conv2D)            (None, 17, 17, 192)  172032      ['activation_786[0][0]']
#
#  conv2d_796 (Conv2D)            (None, 17, 17, 192)  172032      ['activation_791[0][0]']
#
#  conv2d_797 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_76[0][0]']
#
#  batch_normalization_784 (Batch  (None, 17, 17, 192)  576        ['conv2d_788[0][0]']
#  Normalization)
#
#  batch_normalization_787 (Batch  (None, 17, 17, 192)  576        ['conv2d_791[0][0]']
#  Normalization)
#
#  batch_normalization_792 (Batch  (None, 17, 17, 192)  576        ['conv2d_796[0][0]']
#  Normalization)
#
#  batch_normalization_793 (Batch  (None, 17, 17, 192)  576        ['conv2d_797[0][0]']
#  Normalization)
#
#  activation_784 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_784[0][0]']
#
#  activation_787 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_787[0][0]']
#
#  activation_792 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_792[0][0]']
#
#  activation_793 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_793[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_784[0][0]',
#                                                                   'activation_787[0][0]',
#                                                                   'activation_792[0][0]',
#                                                                   'activation_793[0][0]']
#
#  conv2d_802 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_798 (Batch  (None, 17, 17, 160)  480        ['conv2d_802[0][0]']
#  Normalization)
#
#  activation_798 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_798[0][0]']
#
#  conv2d_803 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_798[0][0]']
#
#  batch_normalization_799 (Batch  (None, 17, 17, 160)  480        ['conv2d_803[0][0]']
#  Normalization)
#
#  activation_799 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_799[0][0]']
#
#  conv2d_799 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_804 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_799[0][0]']
#
#  batch_normalization_795 (Batch  (None, 17, 17, 160)  480        ['conv2d_799[0][0]']
#  Normalization)
#
#  batch_normalization_800 (Batch  (None, 17, 17, 160)  480        ['conv2d_804[0][0]']
#  Normalization)
#
#  activation_795 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_795[0][0]']
#
#  activation_800 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_800[0][0]']
#
#  conv2d_800 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_795[0][0]']
#
#  conv2d_805 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_800[0][0]']
#
#  batch_normalization_796 (Batch  (None, 17, 17, 160)  480        ['conv2d_800[0][0]']
#  Normalization)
#
#  batch_normalization_801 (Batch  (None, 17, 17, 160)  480        ['conv2d_805[0][0]']
#  Normalization)
#
#  activation_796 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_796[0][0]']
#
#  activation_801 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_801[0][0]']
#
#  average_pooling2d_77 (AverageP  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_798 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_801 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_796[0][0]']
#
#  conv2d_806 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_801[0][0]']
#
#  conv2d_807 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_77[0][0]']
#
#  batch_normalization_794 (Batch  (None, 17, 17, 192)  576        ['conv2d_798[0][0]']
#  Normalization)
#
#  batch_normalization_797 (Batch  (None, 17, 17, 192)  576        ['conv2d_801[0][0]']
#  Normalization)
#
#  batch_normalization_802 (Batch  (None, 17, 17, 192)  576        ['conv2d_806[0][0]']
#  Normalization)
#
#  batch_normalization_803 (Batch  (None, 17, 17, 192)  576        ['conv2d_807[0][0]']
#  Normalization)
#
#  activation_794 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_794[0][0]']
#
#  activation_797 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_797[0][0]']
#
#  activation_802 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_802[0][0]']
#
#  activation_803 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_803[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_794[0][0]',
#                                                                   'activation_797[0][0]',
#                                                                   'activation_802[0][0]',
#                                                                   'activation_803[0][0]']
#
#  conv2d_812 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_808 (Batch  (None, 17, 17, 160)  480        ['conv2d_812[0][0]']
#  Normalization)
#
#  activation_808 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_808[0][0]']
#
#  conv2d_813 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_808[0][0]']
#
#  batch_normalization_809 (Batch  (None, 17, 17, 160)  480        ['conv2d_813[0][0]']
#  Normalization)
#
#  activation_809 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_809[0][0]']
#
#  conv2d_809 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_814 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_809[0][0]']
#
#  batch_normalization_805 (Batch  (None, 17, 17, 160)  480        ['conv2d_809[0][0]']
#  Normalization)
#
#  batch_normalization_810 (Batch  (None, 17, 17, 160)  480        ['conv2d_814[0][0]']
#  Normalization)
#
#  activation_805 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_805[0][0]']
#
#  activation_810 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_810[0][0]']
#
#  conv2d_810 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_805[0][0]']
#
#  conv2d_815 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_810[0][0]']
#
#  batch_normalization_806 (Batch  (None, 17, 17, 160)  480        ['conv2d_810[0][0]']
#  Normalization)
#
#  batch_normalization_811 (Batch  (None, 17, 17, 160)  480        ['conv2d_815[0][0]']
#  Normalization)
#
#  activation_806 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_806[0][0]']
#
#  activation_811 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_811[0][0]']
#
#  average_pooling2d_78 (AverageP  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_808 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_811 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_806[0][0]']
#
#  conv2d_816 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_811[0][0]']
#
#  conv2d_817 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_78[0][0]']
#
#  batch_normalization_804 (Batch  (None, 17, 17, 192)  576        ['conv2d_808[0][0]']
#  Normalization)
#
#  batch_normalization_807 (Batch  (None, 17, 17, 192)  576        ['conv2d_811[0][0]']
#  Normalization)
#
#  batch_normalization_812 (Batch  (None, 17, 17, 192)  576        ['conv2d_816[0][0]']
#  Normalization)
#
#  batch_normalization_813 (Batch  (None, 17, 17, 192)  576        ['conv2d_817[0][0]']
#  Normalization)
#
#  activation_804 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_804[0][0]']
#
#  activation_807 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_807[0][0]']
#
# ...
#
#  batch_normalization_834 (Batch  (None, 8, 8, 448)   1344        ['conv2d_838[0][0]']
#  Normalization)
#
#  activation_834 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_834[0][0]']
#
#  conv2d_835 (Conv2D)            (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_839 (Conv2D)            (None, 8, 8, 384)    1548288     ['activation_834[0][0]']
#
#  batch_normalization_831 (Batch  (None, 8, 8, 384)   1152        ['conv2d_835[0][0]']
#  Normalization)
#
#  batch_normalization_835 (Batch  (None, 8, 8, 384)   1152        ['conv2d_839[0][0]']
#  Normalization)
#
#  activation_831 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_831[0][0]']
#
#  activation_835 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_835[0][0]']
#
#  conv2d_836 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_831[0][0]']
#
#  conv2d_837 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_831[0][0]']
#
#  conv2d_840 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_835[0][0]']
#
#  conv2d_841 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_835[0][0]']
#
#  average_pooling2d_80 (AverageP  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_834 (Conv2D)            (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_832 (Batch  (None, 8, 8, 384)   1152        ['conv2d_836[0][0]']
#  Normalization)
#
#  batch_normalization_833 (Batch  (None, 8, 8, 384)   1152        ['conv2d_837[0][0]']
#  Normalization)
#
#  batch_normalization_836 (Batch  (None, 8, 8, 384)   1152        ['conv2d_840[0][0]']
#  Normalization)
#
#  batch_normalization_837 (Batch  (None, 8, 8, 384)   1152        ['conv2d_841[0][0]']
#  Normalization)
#
#  conv2d_842 (Conv2D)            (None, 8, 8, 192)    245760      ['average_pooling2d_80[0][0]']
#
#  batch_normalization_830 (Batch  (None, 8, 8, 320)   960         ['conv2d_834[0][0]']
#  Normalization)
#
#  activation_832 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_832[0][0]']
#
#  activation_833 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_833[0][0]']
#
#  activation_836 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_836[0][0]']
#
#  activation_837 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_837[0][0]']
#
#  batch_normalization_838 (Batch  (None, 8, 8, 192)   576         ['conv2d_842[0][0]']
#  Normalization)
#
#  activation_830 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_830[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_832[0][0]',
#                                                                   'activation_833[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 8, 8, 768)    0           ['activation_836[0][0]',
#                                                                   'activation_837[0][0]']
#
#  activation_838 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_838[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_830[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'activation_838[0][0]']
#
#  conv2d_847 (Conv2D)            (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_843 (Batch  (None, 8, 8, 448)   1344        ['conv2d_847[0][0]']
#  Normalization)
#
#  activation_843 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_843[0][0]']
#
#  conv2d_844 (Conv2D)            (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_848 (Conv2D)            (None, 8, 8, 384)    1548288     ['activation_843[0][0]']
#
#  batch_normalization_840 (Batch  (None, 8, 8, 384)   1152        ['conv2d_844[0][0]']
#  Normalization)
#
#  batch_normalization_844 (Batch  (None, 8, 8, 384)   1152        ['conv2d_848[0][0]']
#  Normalization)
#
#  activation_840 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_840[0][0]']
#
#  activation_844 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_844[0][0]']
#
#  conv2d_845 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_840[0][0]']
#
#  conv2d_846 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_840[0][0]']
#
#  conv2d_849 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_844[0][0]']
#
#  conv2d_850 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_844[0][0]']
#
#  average_pooling2d_81 (AverageP  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_843 (Conv2D)            (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_841 (Batch  (None, 8, 8, 384)   1152        ['conv2d_845[0][0]']
#  Normalization)
#
#  batch_normalization_842 (Batch  (None, 8, 8, 384)   1152        ['conv2d_846[0][0]']
#  Normalization)
#
#  batch_normalization_845 (Batch  (None, 8, 8, 384)   1152        ['conv2d_849[0][0]']
#  Normalization)
#
#  batch_normalization_846 (Batch  (None, 8, 8, 384)   1152        ['conv2d_850[0][0]']
#  Normalization)
#
#  conv2d_851 (Conv2D)            (None, 8, 8, 192)    393216      ['average_pooling2d_81[0][0]']
#
#  batch_normalization_839 (Batch  (None, 8, 8, 320)   960         ['conv2d_843[0][0]']
#  Normalization)
#
#  activation_841 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_841[0][0]']
#
#  activation_842 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_842[0][0]']
#
#  activation_845 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_845[0][0]']
#
#  activation_846 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_846[0][0]']
#
#  batch_normalization_847 (Batch  (None, 8, 8, 192)   576         ['conv2d_851[0][0]']
#  Normalization)
#
#  activation_839 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_839[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_841[0][0]',
#                                                                   'activation_842[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 8, 8, 768)    0           ['activation_845[0][0]',
#                                                                   'activation_846[0][0]']
#
#  activation_847 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_847[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_839[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_11[0][0]',
#                                                                   'activation_847[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# Modelling WITH Transfer Learning
from tensorflow.keras.layers import Input

# Here we will prepare model as per our requirements

print("Summary of Custom inception_v3 model.\n")
print("1) We setup input layer and 2) We removed top (last) layer. \n")

# let us prepare our input_layer to pass our image size. default is (224,224,3). we will change it to (224,224,3)
input_layer=layers.Input(shape=(48,48,3))

# initialize the transfer model inception_v3 with appropriate properties per our need.
# we are passing paramers as following
# 1) weights='imagenet' - Using this we are carring weights as of original weights.
# 2) input_tensor to pass the inception_v3 using input_tensor
# 3) we want to change the last layer so we are not including top layer
model_inception_v3=InceptionV3(weights='imagenet',input_tensor=input_layer,include_top=False)

# See the summary of the model with our properties.
model_inception_v3.summary()
# Out:
# Summary of Custom inception_v3 model.
#
# 1) We setup input layer and 2) We removed top (last) layer.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-44d04857d57f> in <module>
#      15 # 2) input_tensor to pass the inception_v3 using input_tensor
#      16 # 3) we want to change the last layer so we are not including top layer
# ---> 17 model_inception_v3=InceptionV3(weights='imagenet',input_tensor=input_layer,include_top=False)
#      18
#      19 # See the summary of the model with our properties.
#
# /usr/local/lib/python3.7/dist-packages/keras/applications/inception_v3.py in InceptionV3(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     284   # mixed 8: 8 x 8 x 1280
#     285   branch3x3 = conv2d_bn(x, 192, 1, 1)
# --> 286   branch3x3 = conv2d_bn(branch3x3, 320, 3, 3, strides=(2, 2), padding='valid')
#     287
#     288   branch7x7x3 = conv2d_bn(x, 192, 1, 1)
#
# /usr/local/lib/python3.7/dist-packages/keras/applications/inception_v3.py in conv2d_bn(x, filters, num_row, num_col, padding, strides, name)
#     404       use_bias=False,
#     405       name=conv_name)(
# --> 406           x)
#     407   x = layers.BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
#     408   x = layers.Activation('relu', name=name)(x)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1961   except errors.InvalidArgumentError as e:
#    1962     # Convert to ValueError for backwards compatibility.
# -> 1963     raise ValueError(e.message)
#    1964
#    1965   return c_op
#
# ValueError: Exception encountered when calling layer "conv2d_1327" (type Conv2D).
#
# Negative dimension size caused by subtracting 3 from 1 for '{{node conv2d_1327/Conv2D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 2, 2, 1], use_cudnn_on_gpu=true](Placeholder, conv2d_1327/Conv2D/ReadVariableOp)' with input shapes: [?,1,1,192], [3,3,192,320].
#
# Call arguments received by layer "conv2d_1327" (type Conv2D):
#   • inputs=tf.Tensor(shape=(None, 1, 1, 192), dtype=float32)

# %%
# access the current last layer of the model and add flatten and dense afte




print("Summary of Custom model_inception_v3 model.\n")
print("1) We flatten the last layer and added 1 Dense layer and 1 output layer.\n")

last_layer=model_inception_v3.output # we are taking last layer of the model

# Add flatten layer: we are extending Neural Network by adding flattn layer
flatten=layers.Flatten()(last_layer) 



# Add dense layer
dense1=layers.Dense(100,activation='relu')(flatten)
dense1=layers.Dense(100,activation='relu')(flatten)
dense1=layers.Dense(100,activation='relu')(flatten)


# Add dense layer to the final output layer
output_layer=layers.Dense(10,activation='softmax')(flatten)

# Creating modle with input and output layer
model=models.Model(inputs=input_layer,outputs=output_layer)

# Summarize the model
model.summary()
# Out:
# Summary of Custom VGG16 model.
#
# 1) We flatten the last layer and added 1 Dense layer and 1 output layer.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-c42790dedf8a> in <module>
#      15
#      16 # Add dense layer
# ---> 17 dense1=layers.Dense(100,activation='relu')(flatten)
#      18 dense1=layers.Dense(100,activation='relu')(flatten)
#      19 dense1=layers.Dense(100,activation='relu')(flatten)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/core/dense.py in build(self, input_shape)
#     139     last_dim = tf.compat.dimension_value(input_shape[-1])
#     140     if last_dim is None:
# --> 141       raise ValueError('The last dimension of the inputs to a Dense layer '
#     142                        'should be defined. Found None. '
#     143                        f'Full input shape received: {input_shape}')
#
# ValueError: The last dimension of the inputs to a Dense layer should be defined. Found None. Full input shape received: (None, None)

# %%
# we will freez all the layers except the last layer

# we are making all the layers intrainable except the last layer
print("We are making all the layers intrainable except the last layer. \n")
for layer in model.layers[:-1]:
    layer.trainable=False
model.summary()

# %%
# Train the Model

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=5)
# print(xtrain)
# print(xtest)
# print(ytrain)
# print(ytest)

print("Splitting data for train and test completed.")

# %%
# Compiling Model

model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

print("Model compilation completed.")
model.summary()

# %%
# Fit the Model

# xtrain2=xtrain.reshape(60000,48,48,3)
# xtest2=xtest.reshape(10000,48,48,3)

history = model.fit(xtrain,ytrain,epochs=10,batch_size=128,verbose=True,validation_data=(xtest,ytest))

print("Fitting the model completed.")

# %%
def plot_value_array(i, predictions_array, true_label): # taking index along with predictions and true label array
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    predicted_label=np.argmax(predictions_array)
    true_label=np.argmax(true_label)

    if predicted_label == 0:
        predicted_label=1
    if true_label == 0:
        true_label=1
    
    thisplot=plt.bar(range(10), predicted_label, color='seashell')
    plt.ylim([0,1])

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('green')
