# %% [markdown]
# <a href="https://colab.research.google.com/github/agolbeny/Alert-app-1/blob/main/InceptionV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from tqdm import tqdm # for progress bar

# Libraries for TensorFlow
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras import models, layers
from tensorflow import keras

# Library for Transfer Learning
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import preprocess_input

print("Importing libraries completed.")
# Out:
# Importing libraries completed.

# %%
(xtrain,ytrain),(xtest,ytest)= keras.datasets.mnist.load_data()

# %%
# Verifying dataset

print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
print(ytrain)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# [5 0 4 ... 5 6 8]

# %%
# Convert the images into 3 channels as MNIST images are Black and White so have 1 channel

xtrain=np.dstack([xtrain] * 3)
xtest=np.dstack([xtest]*3)
xtrain.shape,xtest.shape
# Out:
# ((60000, 28, 84), (10000, 28, 84))

# %%
# Reshape images as per the tensor format required by tensorflow

xtrain = xtrain.reshape(-1, 28,28,3)
xtest= xtest.reshape (-1,28,28,3)
xtrain.shape,xtest.shape
# Out:
# ((60000, 28, 28, 3), (10000, 28, 28, 3))

# %%
from tensorflow.keras.utils import img_to_array, array_to_img

xtrain = np.asarray([img_to_array(array_to_img(im, scale=False).resize((80,80))) for im in xtrain])
xtest = np.asarray([img_to_array(array_to_img(im, scale=False).resize((80,80))) for im in xtest])
#train_x = preprocess_input(x)
xtrain.shape, xtest.shape
# Out:
# ((60000, 80, 80, 3), (10000, 80, 80, 3))

# %%
# listing the folders containing images

# preparing array that can be used later

class_names=['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
print(class_names)

val_class_names =['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
print(val_class_names)

test_class_names=['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
print(test_class_names)

# Function to know the name of the element

def Get_Element_Name(argument):
    switcher = {
        0: "Zero",
        1: "One",
        2: "Two",
        3: "Three",
        4: "Four",
        5: "Five",
        6: "Six",
        7: "Seven",
        8: "Eight",
        9: "Nine",
    }
    return switcher.get(argument, "Invalid")

print(Get_Element_Name(0))
# Out:
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# Zero

# %%
# Preparing data

x=[] # to store array value of the images
x=xtrain
y=[] # to store the labels of the images
y=ytrain

test_images=[]
test_images=xtest
test_images_Original=[]
test_images_Original=xtest
test_image_label=[] # to store the labels of the images
test_image_label=ytest

val_images=[]
val_images=xtest
val_images_Original=[]
val_images_Original=xtest
val_image_label=[] # to store the labels of the images
val_image_label=ytest # to store the labels of the images

print("Preparing Dataset Completed.")
# Out:
# Preparing Dataset Completed.

# %%
# Verifying the output

# Training Dataset
print("Training Dataset")

x=np.array(x) # Converting to np arrary to pass to the model
print(x.shape)

y=to_categorical(y) # onehot encoding of the labels
# print(y)
print(y.shape)

# Test Dataset
print("Test Dataset")

test_images=np.array(test_images) 
print(test_images.shape)

test_image_label=to_categorical(test_image_label) # onehot encoding of the labels)
print(test_image_label.shape)

# Validation Dataset
print("Validation Dataset")

val_images=np.array(val_images) 
print(val_images.shape)

val_image_label=to_categorical(val_image_label) # onehot encoding of the labels)
print(val_image_label.shape)
# Out:
# Training Dataset
# (60000, 80, 80, 3)
# (60000, 10)
# Test Dataset
# (10000, 80, 80, 3)
# (10000, 10)
# Validation Dataset
# (10000, 80, 80, 3)
# (10000, 10)

# %%
# Check properties of the model that we are going to use for Transfer Learning

print("Summary of default inception_v3 model.\n")

# we are using VGG16 for transfer learnin here. So we have imported it
from tensorflow.keras.applications.inception_v3 import InceptionV3

# initializing model with weights='imagenet'i.e. we are carring its original weights
model_inception_v3=InceptionV3(weights='imagenet')

# display the summary to see the properties of the model
model_inception_v3.summary()
# Out:
# Summary of default inception_v3 model.

# %%
# Modelling WITH Transfer Learning
from tensorflow.keras.layers import Input

# Here we will prepare model as per our requirements

print("Summary of Custom inception_v3 model.\n")
print("1) We setup input layer and 2) We removed top (last) layer. \n")

# let us prepare our input_layer to pass our image size. default is (224,224,3). we will change it to (224,224,3)
input_layer=layers.Input(shape=(80,80,3))

# initialize the transfer model inception_v3 with appropriate properties per our need.
# we are passing paramers as following
# 1) weights='imagenet' - Using this we are carring weights as of original weights.
# 2) input_tensor to pass the inception_v3 using input_tensor
# 3) we want to change the last layer so we are not including top layer
model_inception_v3=InceptionV3(weights='imagenet',input_tensor=input_layer,include_top=False)

# See the summary of the model with our properties.
model_inception_v3.summary()
# Out:
# Summary of Custom inception_v3 model.
#
# 1) We setup input layer and 2) We removed top (last) layer.
#
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d_166 (Conv2D)            (None, 39, 39, 32)   864         ['input_3[0][0]']
#
#  batch_normalization_165 (Batch  (None, 39, 39, 32)  96          ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_165 (Activation)    (None, 39, 39, 32)   0           ['batch_normalization_165[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 37, 37, 32)   9216        ['activation_165[0][0]']
#
#  batch_normalization_166 (Batch  (None, 37, 37, 32)  96          ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_166[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 37, 37, 64)   18432       ['activation_166[0][0]']
#
#  batch_normalization_167 (Batch  (None, 37, 37, 64)  192         ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 37, 37, 64)   0           ['batch_normalization_167[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 18, 18, 64)  0           ['activation_167[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 18, 18, 80)   5120        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_168 (Batch  (None, 18, 18, 80)  240         ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_168 (Activation)    (None, 18, 18, 80)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 16, 16, 192)  138240      ['activation_168[0][0]']
#
#  batch_normalization_169 (Batch  (None, 16, 16, 192)  576        ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_169[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 192)   0           ['activation_169[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_173 (Batch  (None, 7, 7, 64)    192         ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_173[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_8[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_173[0][0]']
#
#  batch_normalization_171 (Batch  (None, 7, 7, 48)    144         ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_174 (Batch  (None, 7, 7, 96)    288         ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_171[0][0]']
#
#  activation_174 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_174[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 7, 7, 192)   0           ['max_pooling2d_8[0][0]']
#  ooling2D)
#
#  conv2d_171 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_8[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_174[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 7, 7, 32)     6144        ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 7, 7, 64)    192         ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_172 (Batch  (None, 7, 7, 64)    192         ['conv2d_173[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 7, 7, 96)    288         ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 7, 7, 32)    96          ['conv2d_177[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_170[0][0]']
#
#  activation_172 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_172[0][0]']
#
#  activation_175 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_175[0][0]']
#
#  activation_176 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_176[0][0]']
#
#  mixed0 (Concatenate)           (None, 7, 7, 256)    0           ['activation_170[0][0]',
#                                                                   'activation_172[0][0]',
#                                                                   'activation_175[0][0]',
#                                                                   'activation_176[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  batch_normalization_180 (Batch  (None, 7, 7, 64)    192         ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_180[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 7, 7, 48)     12288       ['mixed0[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_180[0][0]']
#
#  batch_normalization_178 (Batch  (None, 7, 7, 48)    144         ['conv2d_179[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 7, 7, 96)    288         ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_178[0][0]']
#
#  activation_181 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_181[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 7, 7, 256)   0           ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_178 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_178[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_181[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 7, 7, 64)     16384       ['average_pooling2d_17[0][0]']
#
#  batch_normalization_177 (Batch  (None, 7, 7, 64)    192         ['conv2d_178[0][0]']
#  Normalization)
#
#  batch_normalization_179 (Batch  (None, 7, 7, 64)    192         ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 7, 7, 96)    288         ['conv2d_183[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 7, 7, 64)    192         ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_177 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_177[0][0]']
#
#  activation_179 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_179[0][0]']
#
#  activation_182 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_182[0][0]']
#
#  activation_183 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_183[0][0]']
#
#  mixed1 (Concatenate)           (None, 7, 7, 288)    0           ['activation_177[0][0]',
#                                                                   'activation_179[0][0]',
#                                                                   'activation_182[0][0]',
#                                                                   'activation_183[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  batch_normalization_187 (Batch  (None, 7, 7, 64)    192         ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_187[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 7, 7, 48)     13824       ['mixed1[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_187[0][0]']
#
#  batch_normalization_185 (Batch  (None, 7, 7, 48)    144         ['conv2d_186[0][0]']
#  Normalization)
#
#  batch_normalization_188 (Batch  (None, 7, 7, 96)    288         ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_185[0][0]']
#
#  activation_188 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_188[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 7, 7, 288)   0           ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_185 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_185[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_188[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 7, 7, 64)     18432       ['average_pooling2d_18[0][0]']
#
#  batch_normalization_184 (Batch  (None, 7, 7, 64)    192         ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 7, 7, 64)    192         ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_189 (Batch  (None, 7, 7, 96)    288         ['conv2d_190[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 7, 7, 64)    192         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_184[0][0]']
#
#  activation_186 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_186[0][0]']
#
#  activation_189 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_189[0][0]']
#
#  activation_190 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_190[0][0]']
#
#  mixed2 (Concatenate)           (None, 7, 7, 288)    0           ['activation_184[0][0]',
#                                                                   'activation_186[0][0]',
#                                                                   'activation_189[0][0]',
#                                                                   'activation_190[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed2[0][0]']
#
#  batch_normalization_192 (Batch  (None, 7, 7, 64)    192         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_192[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 7, 7, 96)    288         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_193[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 3, 3, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 3, 3, 96)     82944       ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 3, 3, 384)   1152        ['conv2d_192[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 3, 3, 96)    288         ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 3, 3, 96)     0           ['batch_normalization_194[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 3, 3, 768)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]',
#                                                                   'max_pooling2d_9[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_199 (Batch  (None, 3, 3, 128)   384         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_199[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_199[0][0]']
#
#  batch_normalization_200 (Batch  (None, 3, 3, 128)   384         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_200[0][0]']
#
#  batch_normalization_196 (Batch  (None, 3, 3, 128)   384         ['conv2d_197[0][0]']
#  Normalization)
#
#  batch_normalization_201 (Batch  (None, 3, 3, 128)   384         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_196[0][0]']
#
#  activation_201 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_196[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_201[0][0]']
#
#  batch_normalization_197 (Batch  (None, 3, 3, 128)   384         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 3, 3, 128)   384         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_197[0][0]']
#
#  activation_202 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_202[0][0]']
#
#  average_pooling2d_19 (AverageP  (None, 3, 3, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_196 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_197[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_202[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_19[0][0]']
#
#  batch_normalization_195 (Batch  (None, 3, 3, 192)   576         ['conv2d_196[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 3, 3, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_203 (Batch  (None, 3, 3, 192)   576         ['conv2d_204[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 3, 3, 192)   576         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_198[0][0]']
#
#  activation_203 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_203[0][0]']
#
#  activation_204 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_204[0][0]']
#
#  mixed4 (Concatenate)           (None, 3, 3, 768)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_203[0][0]',
#                                                                   'activation_204[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_209 (Batch  (None, 3, 3, 160)   480         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_209[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_209[0][0]']
#
#  batch_normalization_210 (Batch  (None, 3, 3, 160)   480         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_210[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_210[0][0]']
#
#  batch_normalization_206 (Batch  (None, 3, 3, 160)   480         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 3, 3, 160)   480         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_206[0][0]']
#
#  activation_211 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_211[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_206[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_211[0][0]']
#
#  batch_normalization_207 (Batch  (None, 3, 3, 160)   480         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 3, 3, 160)   480         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_207[0][0]']
#
#  activation_212 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 3, 3, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_206 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_207[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_212[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_20[0][0]']
#
#  batch_normalization_205 (Batch  (None, 3, 3, 192)   576         ['conv2d_206[0][0]']
#  Normalization)
#
#  batch_normalization_208 (Batch  (None, 3, 3, 192)   576         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 3, 3, 192)   576         ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 3, 3, 192)   576         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_205[0][0]']
#
#  activation_208 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_208[0][0]']
#
#  activation_213 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_214[0][0]']
#
#  mixed5 (Concatenate)           (None, 3, 3, 768)    0           ['activation_205[0][0]',
#                                                                   'activation_208[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_219 (Batch  (None, 3, 3, 160)   480         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_219[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_219[0][0]']
#
#  batch_normalization_220 (Batch  (None, 3, 3, 160)   480         ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_220[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_220[0][0]']
#
#  batch_normalization_216 (Batch  (None, 3, 3, 160)   480         ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 3, 3, 160)   480         ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_216[0][0]']
#
#  activation_221 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_221[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_216[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_221[0][0]']
#
#  batch_normalization_217 (Batch  (None, 3, 3, 160)   480         ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_222 (Batch  (None, 3, 3, 160)   480         ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_217 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_217[0][0]']
#
#  activation_222 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_222[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 3, 3, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_216 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_217[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_222[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_21[0][0]']
#
#  batch_normalization_215 (Batch  (None, 3, 3, 192)   576         ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_218 (Batch  (None, 3, 3, 192)   576         ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 3, 3, 192)   576         ['conv2d_224[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 3, 3, 192)   576         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_215[0][0]']
#
#  activation_218 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_218[0][0]']
#
#  activation_223 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_223[0][0]']
#
#  activation_224 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_224[0][0]']
#
#  mixed6 (Concatenate)           (None, 3, 3, 768)    0           ['activation_215[0][0]',
#                                                                   'activation_218[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_224[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 1, 1, 1280)   0           ['activation_236[0][0]',
#                                                                   'activation_240[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 1, 1, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_245 (Batch  (None, 1, 1, 448)   1344        ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_245[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 1, 1, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_245[0][0]']
#
#  batch_normalization_242 (Batch  (None, 1, 1, 384)   1152        ['conv2d_243[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 1, 1, 384)   1152        ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_242[0][0]']
#
#  activation_246 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_246[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_242[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_242[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_246[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_246[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 1, 1, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_242 (Conv2D)            (None, 1, 1, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_243 (Batch  (None, 1, 1, 384)   1152        ['conv2d_244[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 1, 1, 384)   1152        ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 1, 1, 384)   1152        ['conv2d_248[0][0]']
#  Normalization)
#
#  batch_normalization_248 (Batch  (None, 1, 1, 384)   1152        ['conv2d_249[0][0]']
#  Normalization)
#
#  conv2d_250 (Conv2D)            (None, 1, 1, 192)    245760      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_241 (Batch  (None, 1, 1, 320)   960         ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_243[0][0]']
#
#  activation_244 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_244[0][0]']
#
#  activation_247 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_247[0][0]']
#
#  activation_248 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_248[0][0]']
#
#  batch_normalization_249 (Batch  (None, 1, 1, 192)   576         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_241 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_241[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 1, 1, 768)    0           ['activation_243[0][0]',
#                                                                   'activation_244[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 1, 1, 768)    0           ['activation_247[0][0]',
#                                                                   'activation_248[0][0]']
#
#  activation_249 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_249[0][0]']
#
#  mixed9 (Concatenate)           (None, 1, 1, 2048)   0           ['activation_241[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_249[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 1, 1, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_254 (Batch  (None, 1, 1, 448)   1344        ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_254[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 1, 1, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_254[0][0]']
#
#  batch_normalization_251 (Batch  (None, 1, 1, 384)   1152        ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 1, 1, 384)   1152        ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_251[0][0]']
#
#  activation_255 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_255[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_251[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_251[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_255[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_255[0][0]']
#
#  average_pooling2d_24 (AverageP  (None, 1, 1, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_251 (Conv2D)            (None, 1, 1, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_252 (Batch  (None, 1, 1, 384)   1152        ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 1, 1, 384)   1152        ['conv2d_254[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 1, 1, 384)   1152        ['conv2d_257[0][0]']
#  Normalization)
#
#  batch_normalization_257 (Batch  (None, 1, 1, 384)   1152        ['conv2d_258[0][0]']
#  Normalization)
#
#  conv2d_259 (Conv2D)            (None, 1, 1, 192)    393216      ['average_pooling2d_24[0][0]']
#
#  batch_normalization_250 (Batch  (None, 1, 1, 320)   960         ['conv2d_251[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_252[0][0]']
#
#  activation_253 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_256[0][0]']
#
#  activation_257 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_257[0][0]']
#
#  batch_normalization_258 (Batch  (None, 1, 1, 192)   576         ['conv2d_259[0][0]']
#  Normalization)
#
#  activation_250 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_250[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 1, 1, 768)    0           ['activation_252[0][0]',
#                                                                   'activation_253[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 1, 1, 768)    0           ['activation_256[0][0]',
#                                                                   'activation_257[0][0]']
#
#  activation_258 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_258[0][0]']
#
#  mixed10 (Concatenate)          (None, 1, 1, 2048)   0           ['activation_250[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_258[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# access the current last layer of the model and add flatten and dense afte




print("Summary of Custom model_inception_v3 model.\n")
print("1) We flatten the last layer and added 1 Dense layer and 1 output layer.\n")

last_layer=model_inception_v3.output # we are taking last layer of the model

# Add flatten layer: we are extending Neural Network by adding flattn layer
flatten=layers.Flatten()(last_layer) 



# Add dense layer
dense1=layers.Dense(100,activation='relu')(flatten)
dense1=layers.Dense(100,activation='relu')(flatten)
dense1=layers.Dense(100,activation='relu')(flatten)


# Add dense layer to the final output layer
output_layer=layers.Dense(10,activation='softmax')(flatten)

# Creating modle with input and output layer
model=models.Model(inputs=input_layer,outputs=output_layer)

# Summarize the model
model.summary()
# Out:
# Summary of Custom model_inception_v3 model.
#
# 1) We flatten the last layer and added 1 Dense layer and 1 output layer.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d_166 (Conv2D)            (None, 39, 39, 32)   864         ['input_3[0][0]']
#
#  batch_normalization_165 (Batch  (None, 39, 39, 32)  96          ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_165 (Activation)    (None, 39, 39, 32)   0           ['batch_normalization_165[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 37, 37, 32)   9216        ['activation_165[0][0]']
#
#  batch_normalization_166 (Batch  (None, 37, 37, 32)  96          ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_166[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 37, 37, 64)   18432       ['activation_166[0][0]']
#
#  batch_normalization_167 (Batch  (None, 37, 37, 64)  192         ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 37, 37, 64)   0           ['batch_normalization_167[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 18, 18, 64)  0           ['activation_167[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 18, 18, 80)   5120        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_168 (Batch  (None, 18, 18, 80)  240         ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_168 (Activation)    (None, 18, 18, 80)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 16, 16, 192)  138240      ['activation_168[0][0]']
#
#  batch_normalization_169 (Batch  (None, 16, 16, 192)  576        ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_169[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 192)   0           ['activation_169[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_173 (Batch  (None, 7, 7, 64)    192         ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_173[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_8[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_173[0][0]']
#
#  batch_normalization_171 (Batch  (None, 7, 7, 48)    144         ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_174 (Batch  (None, 7, 7, 96)    288         ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_171[0][0]']
#
#  activation_174 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_174[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 7, 7, 192)   0           ['max_pooling2d_8[0][0]']
#  ooling2D)
#
#  conv2d_171 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_8[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_174[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 7, 7, 32)     6144        ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 7, 7, 64)    192         ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_172 (Batch  (None, 7, 7, 64)    192         ['conv2d_173[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 7, 7, 96)    288         ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 7, 7, 32)    96          ['conv2d_177[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_170[0][0]']
#
#  activation_172 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_172[0][0]']
#
#  activation_175 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_175[0][0]']
#
#  activation_176 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_176[0][0]']
#
#  mixed0 (Concatenate)           (None, 7, 7, 256)    0           ['activation_170[0][0]',
#                                                                   'activation_172[0][0]',
#                                                                   'activation_175[0][0]',
#                                                                   'activation_176[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  batch_normalization_180 (Batch  (None, 7, 7, 64)    192         ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_180[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 7, 7, 48)     12288       ['mixed0[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_180[0][0]']
#
#  batch_normalization_178 (Batch  (None, 7, 7, 48)    144         ['conv2d_179[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 7, 7, 96)    288         ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_178[0][0]']
#
#  activation_181 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_181[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 7, 7, 256)   0           ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_178 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_178[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_181[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 7, 7, 64)     16384       ['average_pooling2d_17[0][0]']
#
#  batch_normalization_177 (Batch  (None, 7, 7, 64)    192         ['conv2d_178[0][0]']
#  Normalization)
#
#  batch_normalization_179 (Batch  (None, 7, 7, 64)    192         ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 7, 7, 96)    288         ['conv2d_183[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 7, 7, 64)    192         ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_177 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_177[0][0]']
#
#  activation_179 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_179[0][0]']
#
#  activation_182 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_182[0][0]']
#
#  activation_183 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_183[0][0]']
#
#  mixed1 (Concatenate)           (None, 7, 7, 288)    0           ['activation_177[0][0]',
#                                                                   'activation_179[0][0]',
#                                                                   'activation_182[0][0]',
#                                                                   'activation_183[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  batch_normalization_187 (Batch  (None, 7, 7, 64)    192         ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_187[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 7, 7, 48)     13824       ['mixed1[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_187[0][0]']
#
#  batch_normalization_185 (Batch  (None, 7, 7, 48)    144         ['conv2d_186[0][0]']
#  Normalization)
#
#  batch_normalization_188 (Batch  (None, 7, 7, 96)    288         ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_185[0][0]']
#
#  activation_188 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_188[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 7, 7, 288)   0           ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_185 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_185[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_188[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 7, 7, 64)     18432       ['average_pooling2d_18[0][0]']
#
#  batch_normalization_184 (Batch  (None, 7, 7, 64)    192         ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 7, 7, 64)    192         ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_189 (Batch  (None, 7, 7, 96)    288         ['conv2d_190[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 7, 7, 64)    192         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_184[0][0]']
#
#  activation_186 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_186[0][0]']
#
#  activation_189 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_189[0][0]']
#
#  activation_190 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_190[0][0]']
#
#  mixed2 (Concatenate)           (None, 7, 7, 288)    0           ['activation_184[0][0]',
#                                                                   'activation_186[0][0]',
#                                                                   'activation_189[0][0]',
#                                                                   'activation_190[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed2[0][0]']
#
#  batch_normalization_192 (Batch  (None, 7, 7, 64)    192         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_192[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 7, 7, 96)    288         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_193[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 3, 3, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 3, 3, 96)     82944       ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 3, 3, 384)   1152        ['conv2d_192[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 3, 3, 96)    288         ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 3, 3, 96)     0           ['batch_normalization_194[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 3, 3, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 3, 3, 768)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]',
#                                                                   'max_pooling2d_9[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_199 (Batch  (None, 3, 3, 128)   384         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_199[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_199[0][0]']
#
#  batch_normalization_200 (Batch  (None, 3, 3, 128)   384         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_200[0][0]']
#
#  batch_normalization_196 (Batch  (None, 3, 3, 128)   384         ['conv2d_197[0][0]']
#  Normalization)
#
#  batch_normalization_201 (Batch  (None, 3, 3, 128)   384         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_196[0][0]']
#
#  activation_201 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_196[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_201[0][0]']
#
#  batch_normalization_197 (Batch  (None, 3, 3, 128)   384         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 3, 3, 128)   384         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_197[0][0]']
#
#  activation_202 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_202[0][0]']
#
#  average_pooling2d_19 (AverageP  (None, 3, 3, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_196 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_197[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_202[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_19[0][0]']
#
#  batch_normalization_195 (Batch  (None, 3, 3, 192)   576         ['conv2d_196[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 3, 3, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_203 (Batch  (None, 3, 3, 192)   576         ['conv2d_204[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 3, 3, 192)   576         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_198[0][0]']
#
#  activation_203 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_203[0][0]']
#
#  activation_204 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_204[0][0]']
#
#  mixed4 (Concatenate)           (None, 3, 3, 768)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_203[0][0]',
#                                                                   'activation_204[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_209 (Batch  (None, 3, 3, 160)   480         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_209[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_209[0][0]']
#
#  batch_normalization_210 (Batch  (None, 3, 3, 160)   480         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_210[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_210[0][0]']
#
#  batch_normalization_206 (Batch  (None, 3, 3, 160)   480         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 3, 3, 160)   480         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_206[0][0]']
#
#  activation_211 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_211[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_206[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_211[0][0]']
#
#  batch_normalization_207 (Batch  (None, 3, 3, 160)   480         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 3, 3, 160)   480         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_207[0][0]']
#
#  activation_212 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 3, 3, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_206 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_207[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_212[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_20[0][0]']
#
#  batch_normalization_205 (Batch  (None, 3, 3, 192)   576         ['conv2d_206[0][0]']
#  Normalization)
#
#  batch_normalization_208 (Batch  (None, 3, 3, 192)   576         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 3, 3, 192)   576         ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 3, 3, 192)   576         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_205[0][0]']
#
#  activation_208 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_208[0][0]']
#
#  activation_213 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_214[0][0]']
#
#  mixed5 (Concatenate)           (None, 3, 3, 768)    0           ['activation_205[0][0]',
#                                                                   'activation_208[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_219 (Batch  (None, 3, 3, 160)   480         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_219[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_219[0][0]']
#
#  batch_normalization_220 (Batch  (None, 3, 3, 160)   480         ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_220[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_220[0][0]']
#
#  batch_normalization_216 (Batch  (None, 3, 3, 160)   480         ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 3, 3, 160)   480         ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_216[0][0]']
#
#  activation_221 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_221[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_216[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_221[0][0]']
#
#  batch_normalization_217 (Batch  (None, 3, 3, 160)   480         ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_222 (Batch  (None, 3, 3, 160)   480         ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_217 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_217[0][0]']
#
#  activation_222 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_222[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 3, 3, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_216 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_217[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_222[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_21[0][0]']
#
#  batch_normalization_215 (Batch  (None, 3, 3, 192)   576         ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_218 (Batch  (None, 3, 3, 192)   576         ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 3, 3, 192)   576         ['conv2d_224[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 3, 3, 192)   576         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_215[0][0]']
#
#  activation_218 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_218[0][0]']
#
#  activation_223 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_223[0][0]']
#
#  activation_224 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_224[0][0]']
#
#  mixed6 (Concatenate)           (None, 3, 3, 768)    0           ['activation_215[0][0]',
#                                                                   'activation_218[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_224[0][0]']
#
# ...
#  conv2d_246 (Conv2D)            (None, 1, 1, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_245 (Batch  (None, 1, 1, 448)   1344        ['conv2d_246[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_245[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 1, 1, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_245[0][0]']
#
#  batch_normalization_242 (Batch  (None, 1, 1, 384)   1152        ['conv2d_243[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 1, 1, 384)   1152        ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_242[0][0]']
#
#  activation_246 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_246[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_242[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_242[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_246[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_246[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 1, 1, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_242 (Conv2D)            (None, 1, 1, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_243 (Batch  (None, 1, 1, 384)   1152        ['conv2d_244[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 1, 1, 384)   1152        ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 1, 1, 384)   1152        ['conv2d_248[0][0]']
#  Normalization)
#
#  batch_normalization_248 (Batch  (None, 1, 1, 384)   1152        ['conv2d_249[0][0]']
#  Normalization)
#
#  conv2d_250 (Conv2D)            (None, 1, 1, 192)    245760      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_241 (Batch  (None, 1, 1, 320)   960         ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_243[0][0]']
#
#  activation_244 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_244[0][0]']
#
#  activation_247 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_247[0][0]']
#
#  activation_248 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_248[0][0]']
#
#  batch_normalization_249 (Batch  (None, 1, 1, 192)   576         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_241 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_241[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 1, 1, 768)    0           ['activation_243[0][0]',
#                                                                   'activation_244[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 1, 1, 768)    0           ['activation_247[0][0]',
#                                                                   'activation_248[0][0]']
#
#  activation_249 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_249[0][0]']
#
#  mixed9 (Concatenate)           (None, 1, 1, 2048)   0           ['activation_241[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_249[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 1, 1, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_254 (Batch  (None, 1, 1, 448)   1344        ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 1, 1, 448)    0           ['batch_normalization_254[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 1, 1, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 1, 1, 384)    1548288     ['activation_254[0][0]']
#
#  batch_normalization_251 (Batch  (None, 1, 1, 384)   1152        ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 1, 1, 384)   1152        ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_251[0][0]']
#
#  activation_255 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_255[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_251[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_251[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_255[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 1, 1, 384)    442368      ['activation_255[0][0]']
#
#  average_pooling2d_24 (AverageP  (None, 1, 1, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_251 (Conv2D)            (None, 1, 1, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_252 (Batch  (None, 1, 1, 384)   1152        ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 1, 1, 384)   1152        ['conv2d_254[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 1, 1, 384)   1152        ['conv2d_257[0][0]']
#  Normalization)
#
#  batch_normalization_257 (Batch  (None, 1, 1, 384)   1152        ['conv2d_258[0][0]']
#  Normalization)
#
#  conv2d_259 (Conv2D)            (None, 1, 1, 192)    393216      ['average_pooling2d_24[0][0]']
#
#  batch_normalization_250 (Batch  (None, 1, 1, 320)   960         ['conv2d_251[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_252[0][0]']
#
#  activation_253 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_256[0][0]']
#
#  activation_257 (Activation)    (None, 1, 1, 384)    0           ['batch_normalization_257[0][0]']
#
#  batch_normalization_258 (Batch  (None, 1, 1, 192)   576         ['conv2d_259[0][0]']
#  Normalization)
#
#  activation_250 (Activation)    (None, 1, 1, 320)    0           ['batch_normalization_250[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 1, 1, 768)    0           ['activation_252[0][0]',
#                                                                   'activation_253[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 1, 1, 768)    0           ['activation_256[0][0]',
#                                                                   'activation_257[0][0]']
#
#  activation_258 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_258[0][0]']
#
#  mixed10 (Concatenate)          (None, 1, 1, 2048)   0           ['activation_250[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_258[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['mixed10[0][0]']
#
#  dense_3 (Dense)                (None, 10)           20490       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 21,823,274
# Trainable params: 21,788,842
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# we will freez all the layers except the last layer

# we are making all the layers intrainable except the last layer
print("We are making all the layers intrainable except the last layer. \n")
for layer in model.layers[:-1]:
    layer.trainable=False
model.summary()
# Out:
# We are making all the layers intrainable except the last layer.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31b332caea87> in <module>
#       3 # we are making all the layers intrainable except the last layer
#       4 print("We are making all the layers intrainable except the last layer. \n")
# ----> 5 for layer in model.layers[:-1]:
#       6     layer.trainable=False
#       7 model.summary()
#
# NameError: name 'model' is not defined

# %%
# Train the Model

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=5)
# print(xtrain)
# print(xtest)
# print(ytrain)
# print(ytest)

print("Splitting data for train and test completed.")

# %%
# Compiling Model

model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

print("Model compilation completed.")
model.summary()

# %%
# Fit the Model

# xtrain2=xtrain.reshape(60000,48,48,3)
# xtest2=xtest.reshape(10000,48,48,3)

history = model.fit(xtrain,ytrain,epochs=10,batch_size=128,verbose=True,validation_data=(xtest,ytest))

print("Fitting the model completed.")

# %%
def plot_value_array(i, predictions_array, true_label): # taking index along with predictions and true label array
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    predicted_label=np.argmax(predictions_array)
    true_label=np.argmax(true_label)

    if predicted_label == 0:
        predicted_label=1
    if true_label == 0:
        true_label=1
    
    thisplot=plt.bar(range(10), predicted_label, color='seashell')
    plt.ylim([0,1])

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('green')
