# %% [markdown]
# <a href="https://colab.research.google.com/github/agolbeny/Machine-Deep-Learning-Projects/blob/main/Dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/20183655/German-Pinscher-standing-near-a-lake.jpg'
 # getting an image using web get
# Out:
# --2022-12-23 17:44:11--  https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/20183655/German-Pinscher-standing-near-a-lake.jpg
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.90.30, 52.216.218.224, 52.217.227.32, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.90.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39734 (39K) [image/jpeg]
# Saving to: ‘German-Pinscher-standing-near-a-lake.jpg’
#
# German-Pinscher-sta 100%[===================>]  38.80K  --.-KB/s    in 0.09s
#
# 2022-12-23 17:44:11 (454 KB/s) - ‘German-Pinscher-standing-near-a-lake.jpg’ saved [39734/39734]

# %%
# libraries that can be used for image processing
# importing the image module from matplotlib library
import matplotlib.image as mping
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mping.imread('/content/German-Pinscher-standing-near-a-lake.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
print(img)
# Out:
# [[[159 164 110]
#   [154 159 105]
#   [147 151 100]
#   ...
#   [129 143  90]
#   [128 145  93]
#   [129 146  94]]
#
#  [[159 163 112]
#   [154 158 107]
#   [148 152 101]
#   ...
#   [128 142  89]
#   [128 145  91]
#   [129 146  94]]
#
#  [[158 162 111]
#   [153 157 106]
#   [148 152 102]
#   ...
#   [128 143  88]
#   [127 144  90]
#   [128 145  91]]
#
#  ...
#
#  [[153 179  78]
#   [151 176  75]
#   [153 178  77]
#   ...
#   [166 194 117]
#   [144 173  93]
#   [139 168  86]]
#
#  [[167 185 103]
#   [168 186 104]
#   [180 197 117]
#   ...
#   [166 196 108]
#   [154 185  91]
#   [153 185  84]]
#
#  [[171 184 115]
#   [168 181 112]
#   [175 186 120]
#   ...
#   [152 183  89]
#   [146 179  72]
#   [155 189  76]]]

# %%
# displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# resizing the image using pillow library
from PIL import Image

# %%
img = Image.open('/content/German-Pinscher-standing-near-a-lake.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array
img_res = mping.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
# converting RGB images to grayscale image using opencv
import cv2

# %%
img = cv2.imread('/content/German-Pinscher-standing-near-a-lake.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (400, 600)

# %%
# cv2.imshow()
# this will display the image, but this will not be allowed in google colab
# from google.colab.patches import cv2_imshow
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7F129571A0A0>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
